# %% [markdown]
# <a href="https://colab.research.google.com/github/Henriquedevb/lista-05/blob/main/lista_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
''' # Disciplina: Probabilidade e Estatística
# Aluno: Henrique fontenele de jesus
# Matricula: 2014290022
# Lista 5

#QUESTÃO 01 ----------------------------------------------------------------------------------------------
import statistics   #Importa a biblioteca para cauculos estatisticos
#Letra A
resultado = statistics.mean([10, 13, 17, 9, 8, 11, 13, 7]) #Armazena em uma variavel o calculo da media simples
print('\nMédia aritimetica simples: ', resultado) #Mostra a media simples
#Letra B
arm = statistics.harmonic_mean([10, 13, 17, 9, 8, 11, 13, 7]) #Armazena em uma variavel o calculo da media harmonica
print('\nMédia harmonica é: ', arm) #Mostra a media armonica
#Letra C
geo = statistics.geometric_mean([10, 13, 17, 9, 8, 11, 13, 7]) #Armazena em uma variavel o calculo da media geometrica
print('\nA média geométrica é: ', geo) #Mostra a media geometrica
#Letra D
moda = statistics.mode([10, 13, 17, 9, 8, 11, 13, 7]) #Armazena em uma variavel o calculo da moda
print('\nA moda é: ', moda) #Mostra a moda
#Letra E
variancia = statistics.variance([10, 13, 17, 9, 8, 11, 13, 7]) #Armazena em uma variavel o calculo da variancia
print('\nA variancia é: ', variancia) #Mostra a variancia
#Letra F
desvio = statistics.stdev([10, 13, 17, 9, 8, 11, 13, 7]) #Armazena em uma variavel o calculo do desvio padrão
print('\nDesvio padrão é: ', desvio, '\n') #Mostra o desvio padrão

#QUESTÃO 02 --------------------------------------------------------------------------------------------
# Disciplina: Probabilidade e Estatística
# Aluno: Henrique fontenele de jesus
# Matricula: 2014290022
# Lista 5

import statistics  #Importa a biblioteca para calculos estatisticos
#DADOS [67, 75, 63, 72, 77, 78, 81, 77, 80]
#Letra A
media = statistics.mean([67, 75, 63, 72, 77, 78, 81, 77, 80]) #Armazena em uma variavel o calculo da media
harmonica = statistics.harmonic_mean([67, 75, 63, 72, 77, 78, 81, 77, 80]) #Armazena em uma variavel a media harmonica
geometrica = statistics.geometric_mean([67, 75, 63, 72, 77, 78, 81, 77, 80]) #Armazena em uma variavel a media geometrica
print('A média aritimetica simples é: {}, harmonica: {} e geometrica: {}'.format(media, harmonica, geometrica)) #Mostra a media hammonica, simples e geometrica
#Letra B
moda = statistics.mode([67, 75, 63, 72, 77, 78, 81, 77, 80]) #Armazena em uma variavel o calculo da moda
print('Moda: {}'.format(moda)) #Mostra a moda
#Letra C
mediana = statistics.median([67, 75, 63, 72, 77, 78, 81, 77, 80]) #Armazena em uma variavel o calculo da mediana
print('Mediana: {}'.format(mediana)) #Mostra a mediana
#Letra D
variancia = statistics.variance([67, 75, 63, 72, 77, 78, 81, 77, 80]) #Armazena na variavel o calculo da variancia
print('Variancia: {}'.format(variancia)) #Mostra a variancia
#Letra E
desvio = statistics.stdev([67, 75, 63, 72, 77, 78, 81, 77, 80])
print('Desvio padrão: {}'.format(desvio))

#QUESTÃO 03 --------------------------------------------------------------------------------------------
# Disciplina: Probabilidade e Estatística
# Aluno: Henrique fontenele de jesus
# Matricula: 2014290022
# Lista 5

#Calcular o coeficiente de variação

import statistics #Importa a biblioteca que faz calculos estatisticos

desvio = statistics.stdev([4.0, 4.5, 5.0, 5.0, 5.5, 6.0, 6.0, 6.5, 6.5, 6.5, 6.5, 7.0, 7.0, 7.0, 7.0, 7.0, 7.0, 7.5, 8.5, 9.0, 9.0, 9.0, 9.5, 10.0, 10.0, 10.5, 11.0, 12.0, 12.5, 13.0, 13.0]) #Armazenando em uma variavel o calculo do desvio com os dados passados pela questão
media = resultado = statistics.mean([4.0, 4.5, 5.0, 5.0, 5.5, 6.0, 6.0, 6.5, 6.5, 6.5, 6.5, 7.0, 7.0, 7.0, 7.0, 7.0, 7.0, 7.5, 8.5, 9.0, 9.0, 9.0, 9.5, 10.0, 10.0, 10.5, 11.0, 12.0, 12.5, 13.0, 13.0]) #Armazenando em uma variavel o calculo da media com os dados passados pela questão
coeficiente = (desvio/media) * 100 #Faz o calculo do coeficiente
print('O coeficiente de variação desse conjunto é: ', coeficiente) #Mostra o coeficiente

#QUESTÃO 04 --------------------------------------------------------------------------------------------
# Disciplina: Probabilidade e Estatística
# Aluno: Henrique fontenele de jesus
# Matricula: 2014290022
# Lista 5

import statistics #Importa a biblioteca que faz calculos estatisticos

#Letra A
producaoMedia = statistics.mean([12, 15, 18, 22, 17, 14, 18, 23, 29, 12]) #Armazena em uma varialvel o caulculo da media
print('O valor da produção média é: ', producaoMedia) #Mostra a media
#Letra B
mediana = statistics.median([12, 15, 18, 22, 17, 14, 18, 23, 29, 12]) #Armazena em uma variavel o calculo da mediana
print('A mediana da produção é: ', mediana) #Mostra a mediana
#Letra C
desvio = statistics.stdev([12, 15, 18, 22, 17, 14, 18, 23, 29, 12]) #Armazena em uma variavel o calculo do desvio
print('O desvio padrão da produção é: ', desvio) #Mostra o desvio

#QUESTÃO 05 --------------------------------------------------------------------------------------------
# Disciplina: Probabilidade e Estatística
# Aluno: Henrique fontenele de jesus
# Matricula: 2014290022
# Lista 5

import statistics #Importa biblioteca para fazer calculos statisticos
from scipy.stats.mstats import gmean
notas = [] #Inicia uma variavel com um vetor vazio

while True: #Inicia um loop infinito
    nota = float(input('Digite uma nota: ')) #Armazena na variavel nota a nota inserida 
    if nota == -999: #Cria uma verificação com a condição de parada
        print('Programa encerrado') #Avisa que o programa foi encerrado
        break #para o programa
    elif nota <0 or nota >10: #Cria uma verificação para saber se a nota é valida de acordo com o enunciado
        print('\nNota invalida, Tente novamente\n') #Avisa que a nota é invalida e que deve ser digitada novamente 
    else: #Faz algo caso as condições acima não sejam utilizadas
        notas.append(nota) #armazena no vetor as notas validas recebidas

#LETRA A
media = statistics.mean(notas) #Faz o calculo da media
print('\nA media aritmética simples é :', media) #Mostra o resultado do calculo
#LETRA B 
harmonica = statistics.harmonic_mean(notas) #Faz o calculo da media armonica
print('A media harmonica é: ', harmonica) #Mostra o resultado do calculo
#LETRA C
geo = gmean(notas) #Faz o calculo da media geometrica
print('A media geometrica é: ', geo) #Mostra o resultado dos calculos
#LETRA D
moda = statistics.mode(notas) #Faz o calculo da moda
print('A moda é: ', moda) #Mostra a moda
#LETRA E
variancia = statistics.variance(notas) #Faz o calculo da variancia
print('A variancia é: ', variancia) #Mostra o resultado dos calculos
#LETRA F
desvio = statistics.stdev(notas) #faz o calculo do desvio
print('O desvio padrão é: ', desvio) #Mostra o resultado dos calculos
#LETRA G
coeficiente = (desvio/media) * 100 #Faz o calculo do coeficiente padrão
print('O coeficiente da variancia é: ', coeficiente) #Mostra o resultado dos calculos

#QUESTÃO 06 --------------------------------------------------------------------------------------------
# Disciplina: Probabilidade e Estatística
# Aluno: Henrique fontenele de jesus
# Matricula: 2014290022
# Lista 5

while True: #Inicia um loop para receber a primeira nota
    nota1 = float(input('Digite a primeira nota: ')) #recebe a nota 1
    if nota1 <0 or nota1 >10: #Verifica se a nota é valida
        print('Nota invalida!') #Avisa que a nota é invalida
    else: #Se não atender a condição anterior
        break #Encerra o loop

while True: #Inicia um loop para receber a segunda nota   
    nota2 = float(input('Digite a segunda nota: ')) #recebe a nota 2
    if nota2 <0 or nota2 >10: #Verifica se a nota é valida
        print('Nota invalida!') #Avisa que a nota é invalida
    else: #Se não atender a condição anterior
        break #Encerra o loop

while True: #Inicia um loop para receber a terceira nota   
    nota3 = float(input('Digite a terceira nota: ')) #recebe a nota 3
    if nota3 <0 or nota3 >10: #Verifica se a nota é valida
        print('Nota invalida!') #Avisa que a nota é invalida
    else: #Se não atender a condição anterior
        break #Encerra o loop

peso1 = 3 #Amazenando o peso 1 de acordo com enunciado
peso2 = 4 #Armazena o peso 2 de acordo com enunciado
peso3 = 3 #Armazena o peso 3 de acordo com o enunciado

ponderada = (nota1*peso1 + nota2*peso2 + nota3*peso3) / (peso1+peso2+peso3) #Faz o calculo da media ponderada
print('A média ponderada é:', ponderada) #Mostra e media ponderada '''
